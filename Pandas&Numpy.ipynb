# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'college_major_career_outcomes_2026.csv')
df.head(10)

# %%
df.tail(6)

# %%
df.describe()

# %%
df.shape

# %%
df.iloc[:,24]

# %%
sum = 0
n = df.shape[0]

for i in range(n):
    sum += i

print("mean:",sum/n)

# %%
// handling missing data
df.isna()

# %%
df.dropna(how = "any")

# %%
df.fillna(value = 5)

# %%
df.to_numpy()
# Out:
# array([['opeid031505-51.07-1', nan, 31505, ..., 'reported', 'reported',
#         'reported'],
#        ['opeid031505-51.35-1', nan, 31505, ..., 'privacy_suppressed',
#         'privacy_suppressed', 'privacy_suppressed'],
#        ['opeid031505-52.04-1', nan, 31505, ..., 'privacy_suppressed',
#         'privacy_suppressed', 'privacy_suppressed'],
#        ...,
#        ['496423-12.04-1', 496423.0, 43003, ..., 'not_available',
#         'not_available', 'not_available'],
#        ['496423-51.35-1', 496423.0, 43003, ..., 'not_available',
#         'not_available', 'not_available'],
#        ['opeid039163-12.04-1', nan, 39163, ..., 'privacy_suppressed',
#         'reported', 'privacy_suppressed']],
#       shape=(227980, 72), dtype=object)
